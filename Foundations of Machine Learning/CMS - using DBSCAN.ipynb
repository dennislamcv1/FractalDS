# %% [markdown]
# # Video 2.4 - Solving our problem using DBSCAN

# %% [markdown]
# ### To perform clustering using DBSCAN you will be following these steps:
#
# 1) __Load the Dataset:__ Import the dataset into the Jupyter notebook environment.
#
# 2) __Feature Selection:__ Choose the features from the dataset that are relevant for the problem statement.
#
# 3) __Pre-process the data:__ Use appropriate pre-processing measures for the problem statement.
#
# 4) __Apply DBSCAN Clustering:__ Use the DBSCAN algorithm to cluster the data based on the different number of clusters.
#
# 5) __Find Optimal values:__ Find the optimal value for eps using k-plot and set the min_samples
#
# 6) __Evaluate and Interpret the Clusters:__ Analyze and interpret the clusters by plotting different features with cluster labels.

# %% [markdown]
# ###  Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step1: Load the dataset

# %%
data_preprocessed = pd.read_csv('data_preprocessed.csv')
data_preprocessed
# Out:
#         SKU_ID        Date  Page_traffic  Revenue($)  Unit_price  Units_sold  \
# 0      SKU1539  2022-04-09        5835.0       46006   22.214389        2071
# 1      SKU1431  2021-05-08        1881.0        8084   11.870778         681
# 2       SKU995  2022-12-24        2477.0       24190   27.645714         875
# 3      SKU1136  2022-10-08        4087.0       23588   16.896848        1396
# 4       SKU528  2022-03-26        1446.0       13446   16.357664         822
# ...        ...         ...           ...         ...         ...         ...
# 19626   SKU199  2021-12-11        4218.0       21416   14.769655        1450
# 19627   SKU800  2022-08-20        2768.0       24035   30.347222         792
# 19628  SKU1474  2022-12-31        4977.0       24313   23.355427        1041
# 19629   SKU291  2022-01-22        8202.0       34176   16.446583        2078
# 19630  SKU1025  2021-02-20        5760.0       15091   12.289088        1228
#
#          Segment  1_Star_Rating  2_Star_Rating  3_Star_Rating  ...  \
# 0       Skincare           99.0           72.0          194.0  ...
# 1       Skincare          118.0           73.0          200.0  ...
# 2         Makeup          108.0           85.0          232.0  ...
# 3         Makeup           82.0           64.0          167.0  ...
# 4      Hair Care           29.0           24.0           88.0  ...
# ...          ...            ...            ...            ...  ...
# 19626     Makeup          156.0          116.0          315.0  ...
# 19627     Makeup          163.0          110.0          322.0  ...
# 19628     Makeup          177.0          127.0          326.0  ...
# 19629     Makeup            0.0            0.0            0.0  ...
# 19630   Skincare           33.0           12.0           52.0  ...
#
#        Sum of Spend  Online_Clicks  Online_Cost  Online_Impressions  \
# 0          0.000000         1271.0  3102.448115            238075.0
# 1          0.000000          494.0  1723.716359             75868.0
# 2          0.000000            0.0     0.000000                 0.0
# 3          0.000000            0.0     0.000000                 0.0
# 4          0.000000            0.0     0.000000                 0.0
# ...             ...            ...          ...                 ...
# 19626      0.000000          918.0  3788.674296            139251.0
# 19627    735.407892         1376.0  6570.373597            233924.0
# 19628      0.000000          521.0  1644.101132             60831.0
# 19629      0.000000          792.0  2310.693285            203561.0
# 19630      0.000000            0.0     0.000000                 0.0
#
#        num_unique_campaigns  Clicks_video  Cost_video  Impressions_video  \
# 0                       6.0        3479.0    40244.28          3856872.0
# 1                       2.0           0.0        0.00                0.0
# 2                       0.0           0.0        0.00                0.0
# 3                       0.0           0.0        0.00                0.0
# 4                       0.0        6024.0    77040.81          7539723.0
# ...                     ...           ...         ...                ...
# 19626                   2.0           0.0        0.00                0.0
# 19627                   6.0           0.0        0.00                0.0
# 19628                   2.0           0.0        0.00                0.0
# 19629                   2.0        3219.0    40244.28          3856872.0
# 19630                   0.0           0.0        0.00                0.0
#
#        num_unique_campaigns_offline  Units_sold>1000
# 0                               2.0                1
# 1                               0.0                0
# 2                               0.0                0
# 3                               0.0                1
# 4                               2.0                0
# ...                             ...              ...
# 19626                           0.0                1
# 19627                           0.0                0
# 19628                           0.0                1
# 19629                           2.0                1
# 19630                           0.0                1
#
# [19631 rows x 29 columns]

# %% [markdown]
# ### Step2: Feature Selection: Create an aggregated dataset and GroupBy SKU_ID

# %%
# Define the aggregation operations
aggregation = {
    
    'Page_traffic':'last',
    'Organic Search Rank': 'last',
    'Image_Count': 'last',
    'Bullet_Count': 'last',
    'Title_Count': 'last',
    'Description_Length': 'last',
    '1_Star_Rating': 'last',
     '2_Star_Rating': 'last',
     '3_Star_Rating': 'last',
     '4_Star_Rating': 'last',
     '5_Star_Rating': 'last',
    'Unit_price':'last',
    'Revenue($)': 'sum',
}

# %%
# Group by 'SKU_ID' and aggregate
# data_selected = data_preprocessed.groupby('SKU_ID').agg(aggregation).reset_index()
data_selected = data_preprocessed.groupby('SKU_ID').agg(aggregation)
data_selected
# Out:
#          Page_traffic  Organic Search Rank  Image_Count  Bullet_Count  \
# SKU_ID
# SKU1011        3903.0                 19.0          5.0           5.0
# SKU1014         598.0                 31.0          0.0           5.0
# SKU1024        4090.0                 37.0          0.0           8.0
# SKU1025        5760.0                  3.0          2.0           6.0
# SKU1036        3088.0                 36.0         12.0           8.0
# ...               ...                  ...          ...           ...
# SKU968          875.0                 19.0          9.0           5.0
# SKU978          655.0                 33.0          0.0           8.0
# SKU989          583.0                 28.0         13.0           6.0
# SKU995         5999.0                  6.0         10.0           7.0
# SKU998         1724.0                 18.0         14.0           7.0
#
#          Title_Count  Description_Length  1_Star_Rating  2_Star_Rating  \
# SKU_ID
# SKU1011         91.0                59.0           49.0           38.0
# SKU1014         79.0                99.0           55.0           26.0
# SKU1024        163.0               158.0           48.0           34.0
# SKU1025         90.0                62.0           33.0           12.0
# SKU1036        126.0               221.0          140.0           78.0
# ...              ...                 ...            ...            ...
# SKU968          85.0                56.0           57.0           39.0
# SKU978         167.0               158.0            0.0            0.0
# SKU989          62.0               122.0          162.0          107.0
# SKU995         152.0               186.0           75.0           56.0
# SKU998         122.0               209.0           55.0           36.0
#
#          3_Star_Rating  4_Star_Rating  5_Star_Rating  Unit_price  Revenue($)
# SKU_ID
# SKU1011           81.0          179.0         1227.0    6.612984     1805434
# SKU1014           64.0          118.0          691.0   20.099526           0
# SKU1024           92.0          205.0         1494.0   12.659214     2340227
# SKU1025           52.0          122.0          917.0   12.289088     2432316
# SKU1036          228.0          474.0         3479.0   18.474910     2839170
# ...                ...            ...            ...         ...         ...
# SKU968           116.0          273.0         1803.0   20.905660           0
# SKU978             0.0           38.0          172.0   14.686888     2211515
# SKU989           277.0          571.0         3809.0   20.905660           0
# SKU995           160.0          355.0         2277.0   22.432875     3160320
# SKU998            82.0          188.0         1163.0   17.989993     2396552
#
# [239 rows x 13 columns]

# %% [markdown]
# ### Step3: Pre-process the data:  Use appropriate pre-processing measures for the problem statement

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the numerical columns
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Create a DataFrame for the scaled data
data_scaled = pd.DataFrame(data_scaled, columns=data_selected.columns, index = data_selected.index)

# Show the first few rows of the scaled DataFrame
data_scaled.head()
# Out:
#          Page_traffic  Organic Search Rank  Image_Count  Bullet_Count  \
# SKU_ID
# SKU1011      0.677839            -0.058121    -0.411446     -1.576290
# SKU1014     -1.121082             0.990253    -1.427309     -1.576290
# SKU1024      0.779623             1.514440    -1.427309      1.486582
# SKU1025      1.688609            -1.455953    -1.020964     -0.555332
# SKU1036      0.234232             1.427076     1.010763      1.486582
#
#          Title_Count  Description_Length  1_Star_Rating  2_Star_Rating  \
# SKU_ID
# SKU1011    -0.551930           -1.284448      -0.272962      -0.177348
# SKU1014    -0.962336           -0.632472      -0.159208      -0.495841
# SKU1024     1.910506            0.329194      -0.291921      -0.283512
# SKU1025    -0.586131           -1.235550      -0.576307      -0.867416
# SKU1036     0.645087            1.356056       1.452308       0.884296
#
#          3_Star_Rating  4_Star_Rating  5_Star_Rating  Unit_price  Revenue($)
# SKU_ID
# SKU1011      -0.377795      -0.313058      -0.263131   -1.727217   -0.062109
# SKU1014      -0.540692      -0.595646      -0.637991   -0.151948   -1.624228
# SKU1024      -0.272391      -0.192611      -0.076401   -1.020999    0.400611
# SKU1025      -0.655678      -0.577116      -0.479935   -1.064231    0.480290
# SKU1036       1.030787       1.053556       1.311841   -0.341708    0.832313

# %%
data_scaled.shape
# Out:
# (239, 13)

# %% [markdown]
# ### Step4: Apply DBSCAN Clustering

# %%
from sklearn.neighbors import NearestNeighbors

# Use Nearest Neighbors to find distances to the 26th nearest neighbor
nn = NearestNeighbors(n_neighbors=26).fit(data_scaled)
distances, indices = nn.kneighbors(data_scaled)

# %%
import numpy as np

# Sort the distances
distances = np.sort(distances, axis=0)
distances = distances[:, 1]
distances
# Out:
# array([0.53697889, 0.53697889, 0.53706317, 0.53706317, 0.57111797,
#        0.57111797, 0.65310787, 0.65310787, 0.7745152 , 0.7745152 ,
#        0.78219289, 0.78219289, 0.82753565, 0.82753565, 0.8618156 ,
#        0.8618156 , 0.89213902, 0.90094542, 0.90418194, 0.90418194,
#        0.96699498, 0.96699498, 0.96896225, 0.96896225, 0.97559779,
#        0.97559779, 1.00031291, 1.01920605, 1.02703337, 1.03053501,
#        1.03053501, 1.05739028, 1.05739028, 1.0796162 , 1.0796162 ,
#        1.09512742, 1.10755602, 1.10755602, 1.11727174, 1.11727174,
#        1.12795355, 1.12795355, 1.13274042, 1.13274042, 1.14700456,
#        1.14700456, 1.15435062, 1.15435062, 1.19325533, 1.19443238,
#        1.19598104, 1.19666232, 1.19666232, 1.19794438, 1.19794438,
#        1.21602344, 1.21857501, 1.21857501, 1.21908007, 1.2382358 ,
#        1.2382358 , 1.23941744, 1.24491908, 1.25324164, 1.254377  ,
#        1.28253443, 1.28253443, 1.2851621 , 1.2851621 , 1.28719739,
#        1.28719739, 1.29226708, 1.29322171, 1.30076126, 1.30076126,
#        1.30158717, 1.30760002, 1.33244737, 1.33348269, 1.33486456,
#        1.33486456, 1.34454832, 1.34615288, 1.36540074, 1.36540074,
#        1.37312454, 1.37427454, 1.37435334, 1.38978212, 1.39387365,
#        1.39442355, 1.4130462 , 1.4165952 , 1.41814387, 1.42751558,
#        1.42751558, 1.43113785, 1.43252071, 1.44367593, 1.44859334,
#        1.47302035, 1.47302035, 1.47312266, 1.47492836, 1.47492836,
#        1.49038742, 1.49127111, 1.49332154, 1.50425431, 1.50564814,
#        1.50564814, 1.50882812, 1.50882812, 1.52972733, 1.53433819,
#        1.53433819, 1.53883012, 1.53883012, 1.54006754, 1.54006754,
#        1.54335276, 1.55162772, 1.57354161, 1.57726787, 1.58261203,
#        1.58727556, 1.59926108, 1.60648501, 1.612638  , 1.61530208,
#        1.6284009 , 1.63136451, 1.63427724, 1.65205118, 1.65284588,
#        1.65752463, 1.66196588, 1.66502318, 1.66502318, 1.66928624,
#        1.67066075, 1.67554558, 1.68034648, 1.68212819, 1.68695113,
#        1.6870815 , 1.68881737, 1.69712582, 1.69746023, 1.70118583,
#        1.70344141, 1.70344141, 1.72035634, 1.72741927, 1.73174656,
#        1.73569125, 1.73569125, 1.73586562, 1.75175394, 1.7520026 ,
#        1.7551943 , 1.75770202, 1.75939932, 1.75939932, 1.76469489,
#        1.77586479, 1.77934904, 1.78433564, 1.78433564, 1.79152192,
#        1.79159593, 1.79318158, 1.80940066, 1.8436536 , 1.84519836,
#        1.86361893, 1.87663882, 1.87790822, 1.88458712, 1.89215203,
#        1.89215203, 1.91523538, 1.91523538, 1.9231892 , 1.9231892 ,
#        1.92515911, 1.9282732 , 1.94200697, 1.94200697, 1.94881141,
#        1.95530992, 1.95643294, 1.95643294, 1.95871767, 1.95918895,
#        1.98326275, 1.98355326, 1.9913306 , 1.99576395, 2.00062565,
#        2.01996788, 2.03633618, 2.05069416, 2.08221431, 2.08914563,
#        2.09670524, 2.10597027, 2.12917271, 2.13885563, 2.16247254,
#        2.17880805, 2.19825021, 2.20428432, 2.20500255, 2.25687605,
#        2.25878199, 2.28355703, 2.30127051, 2.30352531, 2.31770018,
#        2.32663855, 2.40430472, 2.44819761, 2.52657982, 2.6078851 ,
#        2.65572401, 2.65911661, 2.69581165, 2.73429281, 2.76511735,
#        2.81984693, 2.81984693, 2.84757439, 2.86605745, 2.97557115,
#        3.12961515, 3.1571622 , 3.39444055, 3.6002858 ])

# %% [markdown]
# ## Step5: Find Optimal values for min_samples and eps

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(distances)
plt.title("k-distance Graph")
plt.xlabel("Data Points sorted by distance")
plt.ylabel("Epsilon")
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=3, min_samples=26)
data_scaled['DBSCAN_cluster'] = dbscan.fit_predict(data_scaled)
data_scaled
# Out:
#          Page_traffic  Organic Search Rank  Image_Count  Bullet_Count  \
# SKU_ID
# SKU1011      0.677839            -0.058121    -0.411446     -1.576290
# SKU1014     -1.121082             0.990253    -1.427309     -1.576290
# SKU1024      0.779623             1.514440    -1.427309      1.486582
# SKU1025      1.688609            -1.455953    -1.020964     -0.555332
# SKU1036      0.234232             1.427076     1.010763      1.486582
# ...               ...                  ...          ...           ...
# SKU968      -0.970311            -0.058121     0.401245     -1.576290
# SKU978      -1.090057             1.164982    -1.427309      1.486582
# SKU989      -1.129247             0.728159     1.213936     -0.555332
# SKU995       1.818697            -1.193860     0.604417      0.465625
# SKU998      -0.508197            -0.145486     1.417108      0.465625
#
#          Title_Count  Description_Length  1_Star_Rating  2_Star_Rating  \
# SKU_ID
# SKU1011    -0.551930           -1.284448      -0.272962      -0.177348
# SKU1014    -0.962336           -0.632472      -0.159208      -0.495841
# SKU1024     1.910506            0.329194      -0.291921      -0.283512
# SKU1025    -0.586131           -1.235550      -0.576307      -0.867416
# SKU1036     0.645087            1.356056       1.452308       0.884296
# ...              ...                 ...            ...            ...
# SKU968     -0.757133           -1.333346      -0.121290      -0.150807
# SKU978      2.047308            0.329194      -1.201954      -1.185909
# SKU989     -1.543745           -0.257585       1.869407       1.653987
# SKU995      1.534300            0.785577       0.219972       0.300392
# SKU998      0.508285            1.160463      -0.159208      -0.230430
#
#          3_Star_Rating  4_Star_Rating  5_Star_Rating  Unit_price  Revenue($)  \
# SKU_ID
# SKU1011      -0.377795      -0.313058      -0.263131   -1.727217   -0.062109
# SKU1014      -0.540692      -0.595646      -0.637991   -0.151948   -1.624228
# SKU1024      -0.272391      -0.192611      -0.076401   -1.020999    0.400611
# SKU1025      -0.655678      -0.577116      -0.479935   -1.064231    0.480290
# SKU1036       1.030787       1.053556       1.311841   -0.341708    0.832313
# ...                ...            ...            ...         ...         ...
# SKU968       -0.042418       0.122405       0.139703   -0.057789   -1.624228
# SKU978       -1.153952      -0.966254      -1.000962   -0.784161    0.289246
# SKU989        1.500315       1.502917       1.542631   -0.057789   -1.624228
# SKU995        0.379198       0.502277       0.471203    0.120594    1.110182
# SKU998       -0.368213      -0.271365      -0.307891   -0.398348    0.449346
#
#          DBSCAN_cluster
# SKU_ID
# SKU1011               0
# SKU1014               0
# SKU1024               0
# SKU1025               0
# SKU1036               0
# ...                 ...
# SKU968                0
# SKU978               -1
# SKU989               -1
# SKU995                0
# SKU998                0
#
# [239 rows x 14 columns]

# %%
# Check the number of clusters and noise points
cluster_counts = data_scaled['DBSCAN_cluster'].value_counts()

cluster_counts
# Out:
# DBSCAN_cluster
#  0    209
# -1     30
# Name: count, dtype: int64
